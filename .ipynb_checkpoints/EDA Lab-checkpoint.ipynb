# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
df = pd.read_csv("/Users/peterwilliams/Downloads/amz_uk_price_prediction_dataset.csv")
print(df)

# %%
df.describe()

# %%
df.nunique()

# %% [markdown]
# ## Business Question: What are the most popular product categories on Amazon UK, and how do they compare in terms of listing frequency?
#
# ### Frequency Tables:
#
# ### Generate a frequency table for the product category.
# ### Which are the top 5 most listed product categories?

# %%
df.keys()

# %%
df_group = df.groupby(["category"])['uid'].count().head(5)
df_group.sort_values(ascending=False)

# %% [markdown]
# ## Visualizations:
#
# ### Display the distribution of products across different categories using a bar chart.
# ### If you face problems understanding the chart, do it for a subset of top categories.
# ### For a subset of top categories, visualize their proportions using a pie chart. Does any category dominate the listings?

# %%
df_group = df_group.sort_values(ascending=False)
plt.bar(df_group.index, df_group.values, color=["green", "blue", "red","yellow", "orange"])
plt.title("Top 5 Categories")
plt.xlabel("Categories")
plt.ylabel("Count")
plt.xticks(rotation=90, ha='right')  # Adjust for better readability
plt.show()

# %%
plt.pie(df_group, 
        labels=df_group.index, 
        autopct="%1.1f%%", 
        colors=["green", "blue", "red","yellow", "orange"])
plt.title("Top 5 Categories")
plt.show()

# %% [markdown]
# ### The top category is 3D printing & scanning.

# %% [markdown]
# # Part 2: Delving into Product Pricing
# ### Business Question: How are products priced on Amazon UK, and are there specific price points or ranges that are more common?
#
# ## Measures of Centrality:
#
# Calculate the mean, median, and mode for the price of products.
# What's the average price point of products listed? How does this compare with the most common price point (mode)?
# Measures of Dispersion:

# %%
df_group_price = df.groupby(["category"])['price'].sum().head(5)
df_group_price.sort_values(ascending=False)

# %%
df_group.describe()

# %%
df_group

# %%
from scipy import stats


mean_price = df["price"].mean()
median_price = df["price"].median()
mode_price = df["price"].mode()[0]  # Mode may return multiple values, take the first one

# %%
mean_price

# %%
median_price

# %%
mode_price

# %%
df_group_stat = df.groupby(["category"])['price'].mean

# %% [markdown]
# ### Determine the variance, standard deviation, range, and interquartile range for product price.
# ### How varied are the product prices? Are there any indicators of a significant spread in prices?
# ### Visualizations:

# %%
df_pd = pd.DataFrame(df_group.describe())
df_pd

# %%
df_group_mean = df.groupby(["category"])['price'].mean().head(20)
df_group_mean.sort_values(ascending=False)

# %%
df_group_price = df_group_mean.sort_values(ascending=False)

plt.figure(figsize=(10, 5))
sns.barplot(x=df_group_mean_sorted.index, y=df_group_mean_sorted.values, palette="Blues_r")
plt.xlabel("Category")
plt.ylabel("Average Price")
plt.title("Average Price per Category (Top 20)")
plt.xticks(rotation=45, ha="right")
plt.show()
# Out:
# /var/folders/2q/9q710plj5b1384hmw3491s7r0000gn/T/ipykernel_9873/4276718967.py:4: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=df_group_mean_sorted.index, y=df_group_mean_sorted.values, palette="Blues_r")

# %% [markdown]
# ## Is there a specific price range where most products fall? Plot a histogram to visualize the distribution of product prices. If its hard to read these diagrams, think why this is, and explain how it could be solved..
# ## Are there products that are priced significantly higher than the rest? Use a box plot to showcase the spread and potential outliers in product pricing.

# %% [markdown]
# ## Calculate the mean, median, and mode for the rating of products.
# ## How do customers generally rate products? Is there a common trend?

# %%
df_group = df.groupby(["category"])['reviews'].describe()
df_group
# Out:
#                                   count         mean           std  min   25%  \
# category
# 3D Printers                       248.0   260.064516   1223.953452  0.0   0.0
# 3D Printing & Scanning           4067.0    31.798623    582.193669  0.0   0.0
# Abrasive & Finishing Products     250.0   428.864000   1371.318188  0.0   7.0
# Action Cameras                   1697.0   175.350029   1262.393551  0.0   0.0
# Adapters                          254.0  6904.051181  21581.605747  0.0  47.0
# ...                                 ...          ...           ...  ...   ...
# Wind Instruments                  250.0   332.976000   1634.976595  0.0   0.0
# Window Treatments                 239.0  2274.025105   6638.054082  0.0  26.5
# Women                           17772.0  1248.115237   5530.773667  0.0  48.0
# Women's Sports & Outdoor Shoes   1959.0   987.296580   3253.344840  0.0  10.0
# eBook Readers & Accessories       246.0   657.390244   1817.356601  0.0   0.0
#
# ...

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[283], line 1
# ----> 1 bins = np.arange(0, df['price'].max() + 10000, 10000)
#       2 bins
#
# NameError: name 'np' is not defined

# %%
mean_rate = df_group["stars"].mean()
median_rate = df_group["stars"].median()
mode_rate = df_group["stars"].mode()[0]

# %%
mean_rate
# Out:
# 2.152836472966065

# %%
median_rate
# Out:
# 0.0

# %%
mode_rate
# Out:
# 0.0

# %%
# customers dont leave reviews.

# %% [markdown]
# ## Measures of Dispersion:
#
# Determine the variance, standard deviation, and interquartile range for product rating.
# Are the ratings consistent, or is there a wide variation in customer feedback?

# %%
std_dev = df["stars"].std()  # Standard deviation
variance = df["stars"].var()  # Variance
range_review = df["stars"].max() - df["stars"].min()

# %%
std_dev
# Out:
# 2.1948653785054697

# %%
variance
# Out:
# 4.81743402976196

# %%
range_review
# Out:
# 5.0

# %% [markdown]
# ## Shape of the Distribution:
#
# Calculate the skewness and kurtosis for the rating column.
# Are the ratings normally distributed, or do they lean towards higher or lower values?

# %%
skewness_price = df['stars'].skew() #se compara con 0
kurtosis_price = df['stars'].kurtosis() #se compara con 3

skewness_price, kurtosis_price
# Out:
# (0.08120735761080985, -1.9260061280432985)

# %% [markdown]
# ## Visualizations:
#
# Plot a histogram to visualize the distribution of product ratings. Is there a specific rating that is more common?

# %%
frequency_table = df['stars'].value_counts()

# %%
frequency_table
# Out:
# stars
# 0.0    1225641
# 4.5     151577
# 4.6     136995
# 4.4     136165
# 5.0     128492
# 4.3     112564
# 4.7      94566
# 4.2      86871
# 4.0      66089
# 4.1      65115
# 4.8      41858
# 3.9      36555
# 3.8      27876
# 3.7      21137
# 3.6      16219
# 3.5      14673
# 3.0      12819
# 4.9      11081
# 3.4      10355
# 1.0       8484
# 3.3       8269
# 3.2       5771
# 3.1       4679
# 2.0       3901
# 2.9       3341
# 2.8       2306
# 2.7       2104
# 2.5       2103
# 2.6       1579
# 2.4       1060
# 2.3        734
# 2.2        602
# 2.1        540
# 1.5        404
# 1.9        300
# 1.8        249
# 1.7        177
# 1.4        149
# 1.6        147
# 1.3         78
# 1.2         23
# 1.1          3
# Name: count, dtype: int64

# %%
df_group_price = df_group_mean.sort_values(ascending=False)

plt.figure(figsize=(10, 5))
sns.barplot(x=df_group_mean_sorted.index, y=df_group_mean_sorted.values, palette="Blues_r")
plt.xlabel("Category")
plt.ylabel("Average Price")
plt.title("Average Price per Category (Top 20)")
plt.xticks(rotation=45, ha="right")
plt.show()
# Out:
# /var/folders/2q/9q710plj5b1384hmw3491s7r0000gn/T/ipykernel_9873/1336205634.py:4: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=df_group_mean_sorted.index, y=df_group_mean_sorted.values, palette="Blues_r")
